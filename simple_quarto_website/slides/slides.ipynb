# %% [markdown]
# ---
# title: "DSAN5000Lab02"
# author: "Xiaoya"
# date: "2024-09-17"
# format:
#   revealjs:
#     slide-number: true
#     theme: white
#     toc: true
#     incremental: true
#
# bibliography: ../reference.bib
# ---

# %% [markdown]
# ## Slide 1: Introduction
#
# Welcome to my Slides
#
# [@srinivasan2015teer]
# - Vivamus lectus euismod ut aliquet dapibus porttitor vulputate consectetur.
# - Anon curae etiam maecenas ligula elementum eget varius enim.
# ---
#
# ## Slide 2: Overview
#
#  Quisque id urna at finibus augue mi elementum lacinia.Luctus viverra
#  mollis suscipit habitant lobortis mollis fames ornare.
# ![Image 1](../images/flower.png)
# ---
#
# ## Slide 3: Details
# Commodo aliquam malesuada commodo, cras hac eleifend?
# ![Image 2](../images/mountain.png)
#
# ## Slide 4: Conclusion
# Luctus viverra mollis suscipit habitant lobortis mollis fames ornare.
#  Molestie nam condimentum sem platea sit penatibus.Cursus urna interdum mauris pharetra tincidunt lobortis odio.

# %%
import matplotlib.pyplot as plt
sizes = [15, 30, 45, 10]
labels = ['A', 'B', 'C', 'D']

plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Pie')
plt.show()
